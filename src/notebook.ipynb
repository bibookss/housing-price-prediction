# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data_path = os.path.join(os.getcwd(), 'data', 'realestate.csv')
columns = ['TransactionDate', 'HouseAge', 'DistanceToNearestMRTStation', 'NumberOfConvenienceStores', 'Latitude', 'Longitude', 'PriceOfUnitArea']
df = pd.read_csv(data_path, names=columns)
df['TransactionDate'] = df['TransactionDate'].astype(str).str.split('.').str[0]

# %%
# Out:
# '2013'

# %%
df
# Out:
#     TransactionDate  HouseAge  DistanceToNearestMRTStation  \
# 1              2012      32.0                     84.87882
# 2              2012      19.5                    306.59470
# 3              2013      13.3                    561.98450
# 4              2013      13.3                    561.98450
# 5              2012       5.0                    390.56840
# ..              ...       ...                          ...
# 410            2013      13.7                   4082.01500
# 411            2012       5.6                     90.45606
# 412            2013      18.8                    390.96960
# 413            2013       8.1                    104.81010
# 414            2013       6.5                     90.45606
#
#      NumberOfConvenienceStores  Latitude  Longitude  PriceOfUnitArea
# 1                           10  24.98298  121.54024             37.9
# 2                            9  24.98034  121.53951             42.2
# ...

# %%
y = df['PriceOfUnitArea']
x1 = df['TransactionDate']
x2 = df['HouseAge']
x3 = df['DistanceToNearestMRTStation']
x4 = df['NumberOfConvenienceStores']
x5 = df['Latitude']
x6 = df['Longitude']

# %%
def hypothesis(x, theta):
    return theta[0] + theta[1] * x

def cost_function(x, y, theta):
    m = len(y)
    return (1 / (2 * m)) * sum((hypothesis(x, theta) - y) ** 2)
